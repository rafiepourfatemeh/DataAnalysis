# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
insurance_data = pd.read_csv(r"C:\\Users\hwi\Desktop\insurance.csv")
insurance_data.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
sb.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sb.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sb.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'],palette="Spectral")
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# ?sb.lmplot

# %%
sb.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data,palette="Spectral")

# %%
sb.stripplot(x=insurance_data['smoker'],y=insurance_data['charges'])
#sb.swarmplot(x=insurance_data['smoker'],y=insurance_data['charges'])
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
sb.histplot(insurance_data['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sb.boxplot(x='sex', y='bmi', data=insurance_data)
plt.title('BMI by Sex')
plt.show()

# %%
sb.countplot(x='smoker', data=insurance_data,palette="Set2")
plt.title('Count of Smokers vs Non-Smokers')
plt.show()

# %%
# ?sb.countplot

# %%
sb.boxplot(x='children', y='charges', data=insurance_data)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
avg_charges = insurance_data.groupby('sex')['charges'].mean().reset_index()
sns.barplot(x='sex', y='charges', data=avg_charges)
plt.title('Average Charges by Sex')
plt.show()

# %%
sb.histplot(insurance_data['bmi'], bins=20, kde=True)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
sb.countplot(x='children', data=insurance_data)
plt.title('Count of Children')
plt.show()
