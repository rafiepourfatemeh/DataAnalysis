# %%
import json
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\Student\Desktop\data1.csv')
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
df.to_string()
# Out:
# '           Car       Model  Volume  Weight  CO2\n0       Toyoty        Aygo    1000     790   99\n1   Mitsubishi  Space Star    1200    1160   95\n2        Skoda      Citigo    1000     929   95\n3         Fiat         500     900     865   90\n4         Mini      Cooper    1500    1140  105\n5           VW         Up!    1000     929  105\n6        Skoda       Fabia    1400    1109   90\n7     Mercedes     A-Class    1500    1365   92\n8         Ford      Fiesta    1500    1112   98\n9         Audi          A1    1600    1150   99\n10     Hyundai         I20    1100     980   99\n11      Suzuki       Swift    1300     990  101\n12        Ford      Fiesta    1000    1112   99\n13       Honda       Civic    1600    1252   94\n14      Hundai         I30    1600    1326   97\n15        Opel       Astra    1600    1330   97\n16         BMW           1    1600    1365   99\n17       Mazda           3    2200    1280  104\n18       Skoda       Rapid    1600    1119  104\n19        Ford   
# ...

# %%
pd.options.display.max_rows=7
#pd.set_option('display.max_rows',None)

# %%
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# ..         ...         ...     ...     ...  ...
# 33         BMW         216    1600    1390  108
# 34        Opel      Zafira    1600    1405  109
# 35    Mercedes         SLK    2500    1395  120
#
# [36 rows x 5 columns]

# %%
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
df.tail()

# %%
s = pd.read_json('data.json')
s.to_string()
# Out:
# '     Duration  Pulse  Maxpulse  Calories\n0          60    110       130     409.1\n1          60    117       145     479.0\n2          60    103       135     340.0\n3          45    109       175     282.4\n4          45    117       148     406.0\n5          60    102       127     300.5\n6          60    110       136     374.0\n7          45    104       134     253.3\n8          30    109       133     195.1\n9          60     98       124     269.0\n10         60    103       147     329.3\n11         60    100       120     250.7\n12         60    106       128     345.3\n13         60    104       132     379.3\n14         60     98       123     275.0\n15         60     98       120     215.2\n16         60    100       120     300.0\n17         45     90       112       NaN\n18         60    103       123     323.0\n19         45     97       125     243.0\n20         60    108       131     364.2\n21         45    100       119     282.0\n22         60    130       101 
# ...

# %%
new_df = df.dropna()

new_df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# ..         ...         ...     ...     ...  ...
# 33         BMW         216    1600    1390  108
# 34        Opel      Zafira    1600    1405  109
# 35    Mercedes         SLK    2500    1395  120
#
# [36 rows x 5 columns]

# %%
df.dropna(inplace = True)
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# ..         ...         ...     ...     ...  ...
# 33         BMW         216    1600    1390  108
# 34        Opel      Zafira    1600    1405  109
# 35    Mercedes         SLK    2500    1395  120
#
# [36 rows x 5 columns]

# %%
df.fillna(130, inplace = True)

# %%
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# ..         ...         ...     ...     ...  ...
# 33         BMW         216    1600    1390  108
# 34        Opel      Zafira    1600    1405  109
# 35    Mercedes         SLK    2500    1395  120
#
# [36 rows x 5 columns]

# %%
x = df["Weight"].mean()
print(x)
df["Weight"].fillna(x, inplace = True)

# %%
x = df["Weight"].median()

df["Weight"].fillna(x, inplace = True)

# %%
x = df["Weight"].mode()[0]

df["Weight"].fillna(x, inplace = True)

# %%
df.loc[7, 'Weight'] = 2500

# %%
for x in df.index:
  if df.loc[x, "Weight"] > 1000:
    df.loc[x, "Weight"] = 1000

# %%
for x in df.index:
  if df.loc[x, "Weight"] > 1000:
    df.drop(x, inplace = True)

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1000   95
# 2        Skoda      Citigo    1000     929   95
# ..         ...         ...     ...     ...  ...
# 33         BMW         216    1600    1000  108
# 34        Opel      Zafira    1600    1000  109
# 35    Mercedes         SLK    2500    1000  120
#
# [36 rows x 5 columns]

# %%
df.corr()
# Out:
#           Volume    Weight       CO2
# Volume  1.000000  0.550963  0.592082
# Weight  0.550963  1.000000  0.232012
# CO2     0.592082  0.232012  1.000000
